# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..") / "src"))
import data_locations
from utils import load_image

# %%
sample_imgs = list(train_good.glob("*.png"))[:5]

plt.figure(figsize=(12, 3))
for i, img_path in enumerate(sample_imgs):
    img = load_image(img_path)
    plt.subplot(1, 5, i+1)
    plt.imshow(img)
    plt.axis("off")

plt.suptitle("Normal (Good) Bottle Images")
plt.show()

# %%
defect_types = [d.name for d in test_path.iterdir() if d.is_dir() and d.name != "good"]
print("Defect types:", defect_types)
# Out:
# Defect types: ['broken_large', 'broken_small', 'contamination']

# %%
defect_type = defect_types[0]

defect_img_path = list((test_path / defect_type).glob("*.png"))[0]
gt_mask_path = list((gt_path / defect_type).glob("*.png"))[0]

img = load_image(defect_img_path)
mask = load_image(gt_mask_path, size=(128,128))[:, :, 0]

plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.title("Defective Image")
plt.imshow(img)
plt.axis("off")

plt.subplot(1,2,2)
plt.title("Ground Truth Mask")
plt.imshow(mask, cmap="gray")
plt.axis("off")

plt.show()
